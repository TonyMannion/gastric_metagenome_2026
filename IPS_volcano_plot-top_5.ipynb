# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter

# %%
df = pd.read_csv('/home/dcm/250513Pat_250728Pat_250930Pat/stats_out/fisher_IPS_20_vs_26_results.txt', sep ='\t')
#otu	Odds_Ratio	P-value	20_pos	20_neg	26_pos	26_neg	FDR_BH	ENTRY_AC	ENTRY_TYPE	ENTRY_NAME
# Thresholds

df["OR_corrected"] = (
    (df["20_pos"] + 0.5) * (df["26_neg"] + 0.5)
) / (
    (df["20_neg"] + 0.5) * (df["26_pos"] + 0.5)
)

df["log2_Odds_Ratio"] = np.log2(df["OR_corrected"])

# Transform p-values
df["neg_log10_pval"] = -np.log10(df["FDR_BH"])


# Define significance
pval_thresh = 0.05
df["significant"] = df["FDR_BH"] < pval_thresh

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(
    df["log2_Odds_Ratio"],
    df["neg_log10_pval"],
    c=df["significant"].map({True: "red", False: "grey"}),
    alpha=0.6,
    s=20
)

# Threshold lines
plt.axhline(-np.log10(pval_thresh), color="blue", linestyle="--")


plt.xlabel("log2_Odds_Ratio")
plt.ylabel("-log10(FDR)")
plt.title("fisher_IPS_20_vs_26_results")
plt.savefig("Figures/fisher_IPS_20_vs_26_results.svg", format="svg", bbox_inches="tight")
plt.savefig("Figures/fisher_IPS_20_vs_26_results.png", format="png", dpi=600, bbox_inches="tight")
plt.show()

#see how many sig IPS are enriched in 20 vs 26 year with pivot table
pd.crosstab(
    df["significant"],
    df["log2_Odds_Ratio"] > 0,
    rownames=["Significant"],
    colnames=["log2_OR > 0"]
)
# Out:
# log2_OR > 0  False  True
# Significant
# False         5558   6113
# True           359   4870

# %%
#add new col to df that labels which group the IPS is enriched in
df["IPS_sig_group"] = np.where(
    df["significant"] == True,
    np.where(df["log2_Odds_Ratio"] > 0, "20_year", "26_year"),
    None  # or keep existing value
)

df_IPS_sig_group = df[['otu', 'IPS_sig_group']].dropna()

df_IPS_sig_group
# Out:
#              otu IPS_sig_group
# 2      IPR000015       20_year
# 3      IPR000021       20_year
# 9      IPR000035       20_year
# 10     IPR000036       20_year
# 16     IPR000059       20_year
# ...          ...           ...
# 16870  IPR056113       20_year
# 16880  IPR056174       20_year
# 16895  IPR056329       20_year
# 16896  IPR056338       20_year
# 16898  IPR056362       20_year
#
# [5229 rows x 2 columns]

# %%
df = pd.read_csv('/home/dcm/250513Pat_250728Pat_250930Pat/stats_out/fisher_Prog_IPS_20_vs_26_results.txt', sep ='\t')
#otu	Odds_Ratio	P-value	20_pos	20_neg	26_pos	26_neg	FDR_BH	ENTRY_AC	ENTRY_TYPE	ENTRY_NAME
# Thresholds

df["OR_corrected"] = (
    (df["20_pos"] + 0.5) * (df["26_neg"] + 0.5)
) / (
    (df["20_neg"] + 0.5) * (df["26_pos"] + 0.5)
)

df["log2_Odds_Ratio"] = np.log2(df["OR_corrected"])

# Transform p-values
df["neg_log10_pval"] = -np.log10(df["FDR_BH"])


# Define significance
pval_thresh = 0.05
df["significant"] = df["FDR_BH"] < pval_thresh

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(
    df["log2_Odds_Ratio"],
    df["neg_log10_pval"],
    c=df["significant"].map({True: "red", False: "grey"}),
    alpha=0.6,
    s=20
)

# Threshold lines
plt.axhline(-np.log10(pval_thresh), color="blue", linestyle="--")


plt.xlabel("log2_Odds_Ratio")
plt.ylabel("-log10(FDR)")
plt.title("fisher_Prog_IPS_20_vs_26_results")
plt.savefig("Figures/fisher_Prog_IPS_20_vs_26_results.svg", format="svg", bbox_inches="tight")
plt.savefig("Figures/fisher_Prog_IPS_20_vs_26_results.png", format="png", dpi=600, bbox_inches="tight")
plt.show()


pd.crosstab(
    df["significant"],
    df["log2_Odds_Ratio"] > 0,
    rownames=["Significant"],
    colnames=["log2_OR > 0"]
)
# Out:
# log2_OR > 0  False  True
# Significant
# False         4784   7565
# True            92   3188

# %%
df = pd.read_csv('/home/dcm/250513Pat_250728Pat_250930Pat/stats_out/fisher_Nonprog_IPS_20_vs_26_results.txt', sep ='\t')
#otu	Odds_Ratio	P-value	20_pos	20_neg	26_pos	26_neg	FDR_BH	ENTRY_AC	ENTRY_TYPE	ENTRY_NAME
# Thresholds

df["OR_corrected"] = (
    (df["20_pos"] + 0.5) * (df["26_neg"] + 0.5)
) / (
    (df["20_neg"] + 0.5) * (df["26_pos"] + 0.5)
)

df["log2_Odds_Ratio"] = np.log2(df["OR_corrected"])

# Transform p-values
df["neg_log10_pval"] = -np.log10(df["FDR_BH"])

# Define significance
pval_thresh = 0.05
df["significant"] = df["FDR_BH"] < pval_thresh

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(
    df["log2_Odds_Ratio"],
    df["neg_log10_pval"],
    c=df["significant"].map({True: "red", False: "grey"}),
    alpha=0.6,
    s=20
)

# Threshold lines
plt.axhline(-np.log10(pval_thresh), color="blue", linestyle="--")


plt.xlabel("log2_Odds_Ratio")
plt.ylabel("-log10(FDR)")
plt.title("fisher_Nonprog_IPS_20_vs_26_results")
plt.savefig("Figures/fisher_Nonprog_IPS_20_vs_26_results.svg", format="svg", bbox_inches="tight")
plt.savefig("Figures/fisher_Nonprog_IPS_20_vs_26_results.png", format="png", dpi=600, bbox_inches="tight")
plt.show()


pd.crosstab(
    df["significant"],
    df["log2_Odds_Ratio"] > 0,
    rownames=["Significant"],
    colnames=["log2_OR > 0"]
)
# Out:
# log2_OR > 0  False  True
# Significant
# False         5662   8708
# True             2    723

# %%
df = pd.read_csv('stats_out/annotations_signif_IPS_feature_ids.txt', sep = '\t', dtype=str)

# %%
len(df)
# Out:
# 1599381

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'contig_id', 'feature_id', 'type', 'location', 'start',
#        'stop', 'strand', 'function', 'aliases', 'plfam', 'pgfam', 'figfam',
#        'evidence_codes', 'nucleotide_sequence', 'aa_sequence', 'qseqid_x',
#        'qlen', 'sseqid', 'slen', 'qseq', 'sseq', 'evalue', 'bitscore',
#        'pident', 'qcovhsp', 'salltitles', 'qseqid_y', 'taxid', 'file',
#        'taxname', 'taxid_rep', 'phylum', 'class', 'order', 'family', 'genus',
#        'species', 'fisher_IPS_20_vs_26_results',
#        'fisher_Nonprog_IPS_20_vs_26_results',
#        'fisher_Prog_IPS_20_vs_26_results', 'fisher_IPS_N_vs_P_results',
#        'fisher_year_20_IPS_N_vs_P_results',
#        'fisher_year_26_IPS_N_vs_P_results'],
#       dtype='object')

# %%
df = pd.merge(df, df_IPS_sig_group, left_on ='fisher_IPS_20_vs_26_results', right_on ='otu', how ='left')
df
# Out:
#         Unnamed: 0                             contig_id  \
# 0                2  NODE_1_length_1111386_cov_135.597736
# 1                5  NODE_1_length_1111386_cov_135.597736
# 2               11  NODE_1_length_1111386_cov_135.597736
# 3               12  NODE_1_length_1111386_cov_135.597736
# 4               17  NODE_1_length_1111386_cov_135.597736
# ...            ...                                   ...
# 1599376      52943    NODE_6944_length_1001_cov_8.335095
# 1599377      52943    NODE_6944_length_1001_cov_8.335095
# 1599378      52944    NODE_6944_length_1001_cov_8.335095
# 1599379      52959    NODE_6952_length_1000_cov_8.826455
# 1599380      52960    NODE_6952_length_1000_cov_8.826455
#
#                     feature_id type  \
# 0            fig|2.65351.peg.3  CDS
# 1            fig|2.65351.peg.6  CDS
# 2           fig|2.65351.peg.12  CDS
# 3           fig|2.65351.peg.13  CDS
# 4           fig|2.65351.peg.18  CDS
# ...                        ...  ...
# 1599376  fig|2.65428.peg.52247  CDS
# 1599377  fig|2.65428.peg.52247  CDS
# 1599378  fig|2.65428.peg.52248  CDS
# 1599379  fig|2.65428.peg.52263  CDS
# 1599380  fig|2.65428.peg.52264  CDS
#
#                                                 location  start   stop strand  \
# 0          NODE_1_length_1111386_cov_135.597736_1648-483   1648   1166      -
# 1         NODE_1_length_1111386_cov_135.597736_4891-1374   4891   3518      -
# 2        NODE_1_length_1111386_cov_135.597736_10627-1026  10627   9602      -
# 3          NODE_1_length_1111386_cov_135.597736_10922+90  10922  11011      +
# 4         NODE_1_length_1111386_cov_135.597736_15352-648  15352  14705      -
# ...                                                  ...    ...    ...    ...
# 1599376         NODE_6944_length_1001_cov_8.335095_3+207      3    209      +
# 1599377         NODE_6944_length_1001_cov_8.335095_3+207      3    209      +
# 1599378       NODE_6944_length_1001_cov_8.335095_389+441    389    829      +
# 1599379       NODE_6952_length_1000_cov_8.826455_702-354    702    349      -
# 1599380       NODE_6952_length_1000_cov_8.826455_896-183    896    714      -
#
#                                                   function aliases  ...  \
# 0                             Acid shock protein precursor     NaN  ...
# 1        Multidrug efflux transporter MdtK/NorM (MATE f...     NaN  ...
# 2                    Purine nucleotide synthesis repressor     NaN  ...
# 3                                     hypothetical protein     NaN  ...
# 4                                           Ribonuclease T     NaN  ...
# ...                                                    ...     ...  ...
# 1599376                                        Cnu protein     NaN  ...
# 1599377                                        Cnu protein     NaN  ...
# 1599378                        Inner membrane protein YdgK     NaN  ...
# 1599379                               hypothetical protein     NaN  ...
# 1599380                               hypothetical protein     NaN  ...
#
#               genus               species fisher_IPS_20_vs_26_results  \
# 0        Raoultella  Raoultella terrigena                   IPR023497
# 1        Raoultella  Raoultella terrigena                   IPR022913
# 2        Raoultella  Raoultella terrigena                   IPR023588
# 3        Raoultella  Raoultella terrigena                   IPR047743
# 4        Raoultella  Raoultella terrigena                   IPR005987
# ...             ...                   ...                         ...
# 1599376  Raoultella  Raoultella terrigena                   IPR036666
# 1599377  Raoultella  Raoultella terrigena                   IPR036666
# 1599378  Raoultella  Raoultella terrigena                   IPR019690
# 1599379  Raoultella  Raoultella terrigena                   IPR045681
# 1599380  Raoultella  Raoultella terrigena                   IPR045646
#
#         fisher_Nonprog_IPS_20_vs_26_results fisher_Prog_IPS_20_vs_26_results  \
# 0                                       NaN                        IPR023497
# 1                                       NaN                        IPR022913
# 2                                       NaN                        IPR023588
# 3                                       NaN                        IPR047743
# 4                                       NaN                              NaN
# ...                                     ...                              ...
# 1599376                                 NaN                        IPR007985
# 1599377                                 NaN                        IPR036666
# 1599378                                 NaN                        IPR019690
# 1599379                                 NaN                              NaN
# 1599380                                 NaN                              NaN
#
#         fisher_IPS_N_vs_P_results fisher_year_20_IPS_N_vs_P_results  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 1599376                       NaN                               NaN
# 1599377                       NaN                               NaN
# 1599378                       NaN                               NaN
# 1599379                       NaN                               NaN
# 1599380                       NaN                               NaN
#
#         fisher_year_26_IPS_N_vs_P_results        otu IPS_sig_group
# 0                                     NaN  IPR023497       20_year
# 1                                     NaN  IPR022913       20_year
# 2                                     NaN  IPR023588       20_year
# 3                                     NaN  IPR047743       20_year
# 4                                     NaN  IPR005987       20_year
# ...                                   ...        ...           ...
# 1599376                               NaN  IPR036666       20_year
# 1599377                               NaN  IPR036666       20_year
# 1599378                               NaN  IPR019690       20_year
# 1599379                               NaN  IPR045681       20_year
# 1599380                               NaN  IPR045646       20_year
#
# [1599381 rows x 46 columns]

# %%
unique_items = df['fisher_IPS_20_vs_26_results'].dropna().unique()
len(unique_items)
# Out:
# 5229

# %%
unique_items = df['species'].dropna().unique()
len(unique_items)
# Out:
# 838

# %%
################
### KEGG
###############

# %%
df_genes = df.dropna(subset=['IPS_fisher_IPS_20_vs_26_results']).drop_duplicates(subset=['feature_id','aa_sequence'])

df_genes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2377066/1942289936.py in ?()
# ----> 1 df_genes = df.dropna(subset=['IPS_fisher_IPS_20_vs_26_results']).drop_duplicates(subset=['feature_id','aa_sequence'])
#       2
#       3 df_genes
#
# ~/env/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6403             ax = self._get_axis(agg_axis)
#    6404             indices = ax.get_indexer_for(subset)
#    6405             check = indices == -1
#    6406             if check.any():
# -> 6407                 raise KeyError(np.array(subset)[check].tolist())
#    6408             agg_obj = self.take(indices, axis=agg_axis)
#    6409
#    6410         if thresh is not no_default:
#
# KeyError: ['IPS_fisher_IPS_20_vs_26_results']

# %%
fasta = (
    ">" + df_genes["feature_id"] + "\n" + df_genes["aa_sequence"]
).str.cat(sep="\n")

with open("output.fasta", "w") as f:
    f.write(fasta)

# %%
#map aa sequences to KO --> run in terminal as off screen bc very slow / big database to search --> takes about 2-4 hrs to finish 400,000 sequences
#!/home/dcm/kofamscan/bin/kofam_scan-1.3.0/exec_annotation output.fasta -o KO.txt --cpu 90 -f mapper

# %%
df_ko = pd.read_csv('KO.txt', sep = '\t', names=['feature_id', 'KO'])

# %%
len(df_ko['KO'].dropna().unique())
# Out:
# 2996

# %%
#https://www.kegg.jp/kegg/rest/keggapi.html#list
#get kegg mapping files for KO to pathways and modules

# !wget -O kegg_pathways.txt https://rest.kegg.jp/list/pathway/
# !wget -O kegg_modules.txt https://rest.kegg.jp/list/module/
# !wget -O kegg_pathway_ko_links.txt https://rest.kegg.jp/link/ko/pathway
# !wget -O kegg_module_ko_links.txt https://rest.kegg.jp/link/ko/module

# %%
df_kegg_pathways = pd.read_csv('kegg_pathways.txt', sep ='\t', names = ['pathway', 'pathway_name'])

#print(df_kegg_pathways.head())

df_kegg_modules = pd.read_csv('kegg_modules.txt', sep ='\t', names = ['module', 'module_name'])

#print(df_kegg_modules.head())

df_kegg_pathway_ko_links = pd.read_csv('kegg_pathway_ko_links.txt', sep ='\t', names = ['pathway', 'KO'])

df_kegg_pathway_ko_links['pathway'] = df_kegg_pathway_ko_links['pathway'].str.replace('path:', '', regex=False)
df_kegg_pathway_ko_links['KO'] = df_kegg_pathway_ko_links['KO'].str.replace('ko:', '', regex=False)

#print(df_kegg_pathway_ko_links.head())

df_kegg_module_ko_links = pd.read_csv('kegg_module_ko_links.txt', sep ='\t', names = ['module', 'KO'])

df_kegg_module_ko_links['module'] = df_kegg_module_ko_links['module'].str.replace('md:', '', regex=False)
df_kegg_module_ko_links['KO'] = df_kegg_module_ko_links['KO'].str.replace('ko:', '', regex=False)

#print(df_kegg_module_ko_links.head())

dfm = pd.merge(df_ko, df_kegg_pathway_ko_links, on = 'KO', how = 'left')
dfm = pd.merge(dfm, df_kegg_pathways, on = 'pathway', how = 'left')
dfm = pd.merge(dfm, df_kegg_module_ko_links, on = 'KO', how = 'left')
dfm = pd.merge(dfm, df_kegg_modules, on = 'module', how = 'left')


dfm
# Out:
#                     feature_id      KO  pathway pathway_name  module  \
# 0            fig|2.65351.peg.3     NaN      NaN          NaN     NaN
# 1            fig|2.65351.peg.6  K26939      NaN          NaN     NaN
# 2           fig|2.65351.peg.12  K03604      NaN          NaN     NaN
# 3           fig|2.65351.peg.12  K02529      NaN          NaN     NaN
# 4           fig|2.65351.peg.13     NaN      NaN          NaN     NaN
# ...                        ...     ...      ...          ...     ...
# 1572889  fig|2.65428.peg.52240  K01826  ko01220          NaN  M00533
# 1572890  fig|2.65428.peg.52247  K05839      NaN          NaN     NaN
# 1572891  fig|2.65428.peg.52248     NaN      NaN          NaN     NaN
# 1572892  fig|2.65428.peg.52263     NaN      NaN          NaN     NaN
# 1572893  fig|2.65428.peg.52264     NaN      NaN          NaN     NaN
#
#                                                module_name
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1572889  Homoprotocatechuate degradation, homoprotocate...
# 1572890                                                NaN
# 1572891                                                NaN
# 1572892                                                NaN
# 1572893                                                NaN
#
# [1572894 rows x 6 columns]

# %%
pivot_df = (
    dfm.dropna(subset=['module_name'])
       .pivot_table(
           index='module_name',
           aggfunc='size',
           fill_value=0
       )
       .sort_values(ascending=False)
       .reset_index(name='count')
)

pivot_df
# Out:
#                                            module_name  count
# 0                                  Methylcitrate cycle  37604
# 1               Citrate cycle (TCA cycle, Krebs cycle)  36746
# 2    Citrate cycle, second carbon oxidation, 2-oxog...  31826
# 3       Reductive citrate cycle (Arnon-Buchanan cycle)  25712
# 4    Methionine biosynthesis, aspartate => homoseri...  25124
# ..                                                 ...    ...
# 256  Phytosterol biosynthesis, squalene 2,3-epoxide...      6
# 257                       Dermatan sulfate degradation      6
# 258    Phosphatidylcholine (PC) biosynthesis, PE => PC      6
# 259                    Cytochrome c oxidase, cbb3-type      6
# 260       Multidrug resistance, efflux pump BpeEF-OprC      4
#
# [261 rows x 2 columns]

# %%
#merge KO pathways to main df
dfm = pd.merge(df, dfm, on = 'feature_id', how = 'left')

dfm
# Out:
#         Unnamed: 0                             contig_id  \
# 0                2  NODE_1_length_1111386_cov_135.597736
# 1                5  NODE_1_length_1111386_cov_135.597736
# 2               11  NODE_1_length_1111386_cov_135.597736
# 3               11  NODE_1_length_1111386_cov_135.597736
# 4               12  NODE_1_length_1111386_cov_135.597736
# ...            ...                                   ...
# 5835854      52943    NODE_6944_length_1001_cov_8.335095
# 5835855      52943    NODE_6944_length_1001_cov_8.335095
# 5835856      52944    NODE_6944_length_1001_cov_8.335095
# 5835857      52959    NODE_6952_length_1000_cov_8.826455
# 5835858      52960    NODE_6952_length_1000_cov_8.826455
#
#                     feature_id type  \
# 0            fig|2.65351.peg.3  CDS
# 1            fig|2.65351.peg.6  CDS
# 2           fig|2.65351.peg.12  CDS
# 3           fig|2.65351.peg.12  CDS
# 4           fig|2.65351.peg.13  CDS
# ...                        ...  ...
# 5835854  fig|2.65428.peg.52247  CDS
# 5835855  fig|2.65428.peg.52247  CDS
# 5835856  fig|2.65428.peg.52248  CDS
# 5835857  fig|2.65428.peg.52263  CDS
# 5835858  fig|2.65428.peg.52264  CDS
#
#                                                 location  start   stop strand  \
# 0          NODE_1_length_1111386_cov_135.597736_1648-483   1648   1166      -
# 1         NODE_1_length_1111386_cov_135.597736_4891-1374   4891   3518      -
# 2        NODE_1_length_1111386_cov_135.597736_10627-1026  10627   9602      -
# 3        NODE_1_length_1111386_cov_135.597736_10627-1026  10627   9602      -
# 4          NODE_1_length_1111386_cov_135.597736_10922+90  10922  11011      +
# ...                                                  ...    ...    ...    ...
# 5835854         NODE_6944_length_1001_cov_8.335095_3+207      3    209      +
# 5835855         NODE_6944_length_1001_cov_8.335095_3+207      3    209      +
# 5835856       NODE_6944_length_1001_cov_8.335095_389+441    389    829      +
# 5835857       NODE_6952_length_1000_cov_8.826455_702-354    702    349      -
# 5835858       NODE_6952_length_1000_cov_8.826455_896-183    896    714      -
#
#                                                   function aliases  ...  \
# 0                             Acid shock protein precursor     NaN  ...
# 1        Multidrug efflux transporter MdtK/NorM (MATE f...     NaN  ...
# 2                    Purine nucleotide synthesis repressor     NaN  ...
# 3                    Purine nucleotide synthesis repressor     NaN  ...
# 4                                     hypothetical protein     NaN  ...
# ...                                                    ...     ...  ...
# 5835854                                        Cnu protein     NaN  ...
# 5835855                                        Cnu protein     NaN  ...
# 5835856                        Inner membrane protein YdgK     NaN  ...
# 5835857                               hypothetical protein     NaN  ...
# 5835858                               hypothetical protein     NaN  ...
#
#         fisher_IPS_N_vs_P_results fisher_year_20_IPS_N_vs_P_results  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 5835854                       NaN                               NaN
# 5835855                       NaN                               NaN
# 5835856                       NaN                               NaN
# 5835857                       NaN                               NaN
# 5835858                       NaN                               NaN
#
#         fisher_year_26_IPS_N_vs_P_results        otu IPS_sig_group      KO  \
# 0                                     NaN  IPR023497       20_year     NaN
# 1                                     NaN  IPR022913       20_year  K26939
# 2                                     NaN  IPR023588       20_year  K03604
# 3                                     NaN  IPR023588       20_year  K02529
# 4                                     NaN  IPR047743       20_year     NaN
# ...                                   ...        ...           ...     ...
# 5835854                               NaN  IPR036666       20_year  K05839
# 5835855                               NaN  IPR036666       20_year  K05839
# 5835856                               NaN  IPR019690       20_year     NaN
# 5835857                               NaN  IPR045681       20_year     NaN
# 5835858                               NaN  IPR045646       20_year     NaN
#
#         pathway pathway_name module module_name
# 0           NaN          NaN    NaN         NaN
# 1           NaN          NaN    NaN         NaN
# 2           NaN          NaN    NaN         NaN
# 3           NaN          NaN    NaN         NaN
# 4           NaN          NaN    NaN         NaN
# ...         ...          ...    ...         ...
# 5835854     NaN          NaN    NaN         NaN
# 5835855     NaN          NaN    NaN         NaN
# 5835856     NaN          NaN    NaN         NaN
# 5835857     NaN          NaN    NaN         NaN
# 5835858     NaN          NaN    NaN         NaN
#
# [5835859 rows x 51 columns]

# %%
dfm.columns
# Out:
# Index(['Unnamed: 0', 'contig_id', 'feature_id', 'type', 'location', 'start',
#        'stop', 'strand', 'function', 'aliases', 'plfam', 'pgfam', 'figfam',
#        'evidence_codes', 'nucleotide_sequence', 'aa_sequence', 'qseqid_x',
#        'qlen', 'sseqid', 'slen', 'qseq', 'sseq', 'evalue', 'bitscore',
#        'pident', 'qcovhsp', 'salltitles', 'qseqid_y', 'taxid', 'file',
#        'taxname', 'taxid_rep', 'phylum', 'class', 'order', 'family', 'genus',
#        'species', 'fisher_IPS_20_vs_26_results',
#        'fisher_Nonprog_IPS_20_vs_26_results',
#        'fisher_Prog_IPS_20_vs_26_results', 'fisher_IPS_N_vs_P_results',
#        'fisher_year_20_IPS_N_vs_P_results',
#        'fisher_year_26_IPS_N_vs_P_results', 'otu', 'IPS_sig_group', 'KO',
#        'pathway', 'pathway_name', 'module', 'module_name'],
#       dtype='object')

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '20_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['module_name'])
               .groupby(['module_name', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='module_name',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 5 species
top_species = species_totals.nlargest(5).index

# Step 5: group species not in top 5 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['module_name', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='module_name',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(25)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

# convert fractions to percentages
final_wide_df_top25 = final_wide_df_top25 * 100

# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)


# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]


# Step 3: plot
ax = final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# Optional: Add labels or adjustments
ax.set_xlabel("Values")
ax.set_ylabel("Categories")
ax.set_title("Top 25 Sorted Columns")

# Get the figure object and save in both formats
fig = ax.get_figure()
fig.savefig("Figures/KEGG_20_year.svg", format="svg", bbox_inches="tight")
fig.savefig("Figures/KEGG_20_year.png", format="png", dpi=300, bbox_inches="tight")

# Display the plot
plt.show()

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '26_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['module_name'])
               .groupby(['module_name', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='module_name',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(5).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['module_name', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='module_name',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(25)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

# convert fractions to percentages
final_wide_df_top25 = final_wide_df_top25 * 100

# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
ax = final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# Optional: Add labels or adjustments
ax.set_xlabel("Values")
ax.set_ylabel("Categories")
ax.set_title("Top 25 Sorted Columns")

# Get the figure object and save in both formats
fig = ax.get_figure()
fig.savefig("Figures/KEGG_26_year.svg", format="svg", bbox_inches="tight")
fig.savefig("Figures/KEGG_26_year.png", format="png", dpi=300, bbox_inches="tight")

# Display the plot
plt.show()

# %%
################
### VFDB
###############

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'contig_id', 'feature_id', 'type', 'location', 'start',
#        'stop', 'strand', 'function', 'aliases', 'plfam', 'pgfam', 'figfam',
#        'evidence_codes', 'nucleotide_sequence', 'aa_sequence', 'qseqid_x',
#        'qlen', 'sseqid', 'slen', 'qseq', 'sseq', 'evalue', 'bitscore',
#        'pident', 'qcovhsp', 'salltitles', 'qseqid_y', 'taxid', 'file',
#        'taxname', 'taxid_rep', 'phylum', 'class', 'order', 'family', 'genus',
#        'species', 'fisher_IPS_20_vs_26_results',
#        'fisher_Nonprog_IPS_20_vs_26_results',
#        'fisher_Prog_IPS_20_vs_26_results', 'fisher_IPS_N_vs_P_results',
#        'fisher_year_20_IPS_N_vs_P_results',
#        'fisher_year_26_IPS_N_vs_P_results', 'otu', 'IPS_sig_group'],
#       dtype='object')

# %%
#filter for only VF with >= 35% sequence identity
df['pident'] = pd.to_numeric(df['pident'], errors='coerce')


df_VF = df[df['pident'] >= 35]

# %%
#pivot IPS by VFDB, lists all VF gene expect nan

pivot_df = (
    df_VF.dropna(subset=['fisher_IPS_20_vs_26_results'])
      .pivot_table(
          index='fisher_IPS_20_vs_26_results',
          values='salltitles',
          aggfunc=lambda x: list(x.unique())
      )
)
pivot_df = pivot_df[~pivot_df['salltitles'].apply(lambda x: len(x) == 1 and (x[0] is np.nan or x[0] == 'nan'))]
pivot_df.to_csv('out.txt', sep = '\t')

# %%
#pivot IPS by VFDB, lists top two VF gene

pivot_df = (
    df_VF.dropna(subset=['fisher_IPS_20_vs_26_results'])
      .pivot_table(
          index='fisher_IPS_20_vs_26_results',
          values='salltitles',
          aggfunc=lambda x: [item for item, count in Counter(x).most_common(2)]
      )
)
pivot_df = pivot_df[~pivot_df['salltitles'].apply(lambda x: len(x) == 1 and (x[0] is np.nan or x[0] == 'nan'))]

pivot_df

pivot_df.to_csv('out.txt', sep = '\t')

# %%
#pivot IPS by VFDB, lists top  VF gene

pivot_df = (
    df_VF.dropna(subset=['fisher_IPS_20_vs_26_results'])
      .pivot_table(
          index='fisher_IPS_20_vs_26_results',
          values='salltitles',
          aggfunc=lambda x: Counter(x.dropna()).most_common(1)[0][0] if len(x.dropna()) > 0 else None
      )
)
pivot_df
# Out:
#                                                                     salltitles
# fisher_IPS_20_vs_26_results
# IPR000015                    VFG018308(gb|WP_001160719) (sthC) fimbrial out...
# IPR000036                    VFG003087(gb|WP_002231174) (pla) plasminogen a...
# IPR000067                    VFG014418(gb|WP_011333049) (fliF) flagellar M-...
# IPR000090                    VFG014429(gb|WP_011534908) (fliG) flagellar mo...
# IPR000101                    VFG047602(gb|WP_206193639) (ggt) gamma-glutamy...
# ...                                                                        ...
# IPR054897                    VFG033029(gb|WP_012581960) (pdgA) Peptidoglyca...
# IPR054913                    VFG001989(gb|YP_002344799) (Cj1416c) sugar nuc...
# IPR054921                    VFG044079(gb|NP_250944) (pvcA) paerucumarin bi...
# IPR055014                    VFG052343(gb|WP_001237694.1) (bapA) biofilm-as...
# IPR055262                    VFG047605(gb|WP_080558930) (ggt) gamma-glutamy...
#
# [1058 rows x 1 columns]

# %%
pivot_df = pivot_df.reset_index()
pivot_df = pivot_df.rename(columns={'salltitles': 'VF_consensus'})
pivot_df
# Out:
#      fisher_IPS_20_vs_26_results  \
# 0                      IPR000015
# 1                      IPR000036
# 2                      IPR000067
# 3                      IPR000090
# 4                      IPR000101
# ...                          ...
# 1053                   IPR054897
# 1054                   IPR054913
# 1055                   IPR054921
# 1056                   IPR055014
# 1057                   IPR055262
#
#                                            VF_consensus
# 0     VFG018308(gb|WP_001160719) (sthC) fimbrial out...
# 1     VFG003087(gb|WP_002231174) (pla) plasminogen a...
# 2     VFG014418(gb|WP_011333049) (fliF) flagellar M-...
# 3     VFG014429(gb|WP_011534908) (fliG) flagellar mo...
# 4     VFG047602(gb|WP_206193639) (ggt) gamma-glutamy...
# ...                                                 ...
# 1053  VFG033029(gb|WP_012581960) (pdgA) Peptidoglyca...
# 1054  VFG001989(gb|YP_002344799) (Cj1416c) sugar nuc...
# 1055  VFG044079(gb|NP_250944) (pvcA) paerucumarin bi...
# 1056  VFG052343(gb|WP_001237694.1) (bapA) biofilm-as...
# 1057  VFG047605(gb|WP_080558930) (ggt) gamma-glutamy...
#
# [1058 rows x 2 columns]

# %%
dfm = pd.merge(df, pivot_df, on = 'fisher_IPS_20_vs_26_results', how = 'left')

# %%
# for feature_ids with <35% VF similiarity, need to remove VF_consensus label
dfm.loc[dfm['pident'] < 35, 'VF_consensus'] = np.nan

# %%
dfm[dfm['pident'] < 35]
# Out:
#         Unnamed: 0                             contig_id  \
# 2               11  NODE_1_length_1111386_cov_135.597736
# 19              35  NODE_1_length_1111386_cov_135.597736
# 20              35  NODE_1_length_1111386_cov_135.597736
# 33              46  NODE_1_length_1111386_cov_135.597736
# 49              78  NODE_1_length_1111386_cov_135.597736
# ...            ...                                   ...
# 1599156      51383    NODE_6057_length_1149_cov_9.146252
# 1599157      51383    NODE_6057_length_1149_cov_9.146252
# 1599158      51383    NODE_6057_length_1149_cov_9.146252
# 1599159      51383    NODE_6057_length_1149_cov_9.146252
# 1599160      51383    NODE_6057_length_1149_cov_9.146252
#
#                     feature_id type  \
# 2           fig|2.65351.peg.12  CDS
# 19          fig|2.65351.peg.36  CDS
# 20          fig|2.65351.peg.36  CDS
# 33          fig|2.65351.peg.47  CDS
# 49          fig|2.65351.peg.79  CDS
# ...                        ...  ...
# 1599156  fig|2.65428.peg.50734  CDS
# 1599157  fig|2.65428.peg.50734  CDS
# 1599158  fig|2.65428.peg.50734  CDS
# 1599159  fig|2.65428.peg.50734  CDS
# 1599160  fig|2.65428.peg.50734  CDS
#
#                                                 location  start   stop strand  \
# 2        NODE_1_length_1111386_cov_135.597736_10627-1026  10627   9602      -
# 19        NODE_1_length_1111386_cov_135.597736_41277-897  41277  40381      -
# 20        NODE_1_length_1111386_cov_135.597736_41277-897  41277  40381      -
# 33       NODE_1_length_1111386_cov_135.597736_51553-1506  51553  50048      -
# 49       NODE_1_length_1111386_cov_135.597736_78450-1179  78450  77272      -
# ...                                                  ...    ...    ...    ...
# 1599156        NODE_6057_length_1149_cov_9.146252_2+1146      2   1147      +
# 1599157        NODE_6057_length_1149_cov_9.146252_2+1146      2   1147      +
# 1599158        NODE_6057_length_1149_cov_9.146252_2+1146      2   1147      +
# 1599159        NODE_6057_length_1149_cov_9.146252_2+1146      2   1147      +
# 1599160        NODE_6057_length_1149_cov_9.146252_2+1146      2   1147      +
#
#                                                   function aliases  ...  \
# 2                    Purine nucleotide synthesis repressor     NaN  ...
# 19       Tetrapartite efflux system, membrane fusion co...     NaN  ...
# 20       Tetrapartite efflux system, membrane fusion co...     NaN  ...
# 33                         Di-tripeptide/H+ symporter DtpA     NaN  ...
# 49              Mannose-6-phosphate isomerase (EC 5.3.1.8)     NaN  ...
# ...                                                    ...     ...  ...
# 1599156                    RNase E specificity factor CsrD     NaN  ...
# 1599157                    RNase E specificity factor CsrD     NaN  ...
# 1599158                    RNase E specificity factor CsrD     NaN  ...
# 1599159                    RNase E specificity factor CsrD     NaN  ...
# 1599160                    RNase E specificity factor CsrD     NaN  ...
#
#                       species fisher_IPS_20_vs_26_results  \
# 2        Raoultella terrigena                   IPR023588
# 19       Raoultella terrigena                   IPR043602
# 20       Raoultella terrigena                   IPR050393
# 33       Raoultella terrigena                   IPR023517
# 49       Raoultella terrigena                   IPR046458
# ...                       ...                         ...
# 1599156  Raoultella terrigena                   IPR001633
# 1599157  Raoultella terrigena                   IPR050706
# 1599158  Raoultella terrigena                   IPR050706
# 1599159  Raoultella terrigena                   IPR035919
# 1599160  Raoultella terrigena                   IPR035919
#
#         fisher_Nonprog_IPS_20_vs_26_results fisher_Prog_IPS_20_vs_26_results  \
# 2                                       NaN                        IPR023588
# 19                                      NaN                        IPR050393
# 20                                      NaN                        IPR050393
# 33                                      NaN                        IPR023517
# 49                                      NaN                        IPR046458
# ...                                     ...                              ...
# 1599156                                 NaN                        IPR035919
# 1599157                                 NaN                        IPR050706
# 1599158                                 NaN                        IPR035919
# 1599159                                 NaN                        IPR050706
# 1599160                                 NaN                        IPR035919
#
#         fisher_IPS_N_vs_P_results fisher_year_20_IPS_N_vs_P_results  \
# 2                             NaN                               NaN
# 19                            NaN                               NaN
# 20                            NaN                               NaN
# 33                            NaN                               NaN
# 49                            NaN                               NaN
# ...                           ...                               ...
# 1599156                       NaN                               NaN
# 1599157                       NaN                               NaN
# 1599158                       NaN                               NaN
# 1599159                       NaN                               NaN
# 1599160                       NaN                               NaN
#
#         fisher_year_26_IPS_N_vs_P_results        otu IPS_sig_group  \
# 2                                     NaN  IPR023588       20_year
# 19                                    NaN  IPR043602       20_year
# 20                                    NaN  IPR050393       20_year
# 33                                    NaN  IPR023517       20_year
# 49                                    NaN  IPR046458       20_year
# ...                                   ...        ...           ...
# 1599156                               NaN  IPR001633       20_year
# 1599157                               NaN  IPR050706       20_year
# 1599158                               NaN  IPR050706       20_year
# 1599159                               NaN  IPR035919       20_year
# 1599160                               NaN  IPR035919       20_year
#
#         VF_consensus
# 2                NaN
# 19               NaN
# 20               NaN
# 33               NaN
# 49               NaN
# ...              ...
# 1599156          NaN
# 1599157          NaN
# 1599158          NaN
# 1599159          NaN
# 1599160          NaN
#
# [102708 rows x 47 columns]

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '20_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['VF_consensus'])
               .groupby(['VF_consensus', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='VF_consensus',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(5).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['VF_consensus', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='VF_consensus',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(10)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

final_wide_df_top25 = final_wide_df_top25 * 100


# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
ax = final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# Optional: Add labels or adjustments
ax.set_xlabel("Values")
ax.set_ylabel("Categories")
ax.set_title("Top 25 Sorted Columns")

# Get the figure object and save in both formats
fig = ax.get_figure()
fig.savefig("Figures/VF_20_year.svg", format="svg", bbox_inches="tight")
fig.savefig("Figures/VF_20_year.png", format="png", dpi=300, bbox_inches="tight")

# Display the plot
plt.show()

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '26_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['VF_consensus'])
               .groupby(['VF_consensus', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='VF_consensus',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(5).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['VF_consensus', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='VF_consensus',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(10)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

final_wide_df_top25 = final_wide_df_top25 * 100


# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
ax = final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# Optional: Add labels or adjustments
ax.set_xlabel("Values")
ax.set_ylabel("Categories")
ax.set_title("Top 25 Sorted Columns")

# Get the figure object and save in both formats
fig = ax.get_figure()
fig.savefig("Figures/VF_26_year.svg", format="svg", bbox_inches="tight")
fig.savefig("Figures/VF_26_year.png", format="png", dpi=300, bbox_inches="tight")

# Display the plot
plt.show()

# %%
################
### IPS 
###############

# %%
#https://ftp.ebi.ac.uk/pub/databases/interpro/releases/latest/entry.list
#!wget -O IPS_metadata.txt https://ftp.ebi.ac.uk/pub/databases/interpro/releases/latest/entry.list

# %%
df_IPS_meta = pd.read_csv('IPS_metadata.txt', sep = '\t')

# %%
dfm = pd.merge(df, df_IPS_meta, left_on = 'fisher_IPS_20_vs_26_results', right_on = 'ENTRY_AC', how = 'left')

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '20_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['ENTRY_NAME'])
               .groupby(['ENTRY_NAME', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='ENTRY_NAME',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(5).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['ENTRY_NAME', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='ENTRY_NAME',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(25)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

final_wide_df_top25 = final_wide_df_top25 * 100


# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
ax = final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# Optional: Add labels or adjustments
ax.set_xlabel("Values")
ax.set_ylabel("Categories")
ax.set_title("Top 25 Sorted Columns")

# Get the figure object and save in both formats
fig = ax.get_figure()
fig.savefig("Figures/IPS_20_year.svg", format="svg", bbox_inches="tight")
fig.savefig("Figures/IPS_20_year.png", format="png", dpi=300, bbox_inches="tight")

# Display the plot
plt.show()

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '26_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['ENTRY_NAME'])
               .groupby(['ENTRY_NAME', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='ENTRY_NAME',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(5).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['ENTRY_NAME', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='ENTRY_NAME',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(25)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

final_wide_df_top25 = final_wide_df_top25 * 100


# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
ax = final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# Optional: Add labels or adjustments
ax.set_xlabel("Values")
ax.set_ylabel("Categories")
ax.set_title("Top 25 Sorted Columns")

# Get the figure object and save in both formats
fig = ax.get_figure()
fig.savefig("Figures/IPS_26_year.svg", format="svg", bbox_inches="tight")
fig.savefig("Figures/IPS_26_year.png", format="png", dpi=300, bbox_inches="tight")

# Display the plot
plt.show()

# %%
######
## CARD
######

# %%
headers = [
    "qseqid",
    "qlen",
    "sseqid",
    "slen",
    "qseq",
    "sseq",
    "evalue",
    "bitscore",
    "pident",
    "qcovhsp",
    "salltitles",
]

df_card = pd.read_csv('CARD_diamond/CARD_cat.txt', sep = '\t', names = headers)
df_card["ARO Accession"] = df_card["sseqid"].str.extract(r"(ARO:\d+)")
df_card_meta = pd.read_csv('/home/dcm/bioinformatic_scripts/blast_databases/CARD-v4.0.1/aro_index.tsv', sep = '\t')
dfm = pd.merge(df_card, df_card_meta, how = 'left', on = "ARO Accession")
dfm

# %%
df = pd.read_csv('/home/dcm//250513Pat_250728Pat_250930Pat/VFDB_diamond/cat_VFDB_out_meta_ips_sig.txt', sep = '\t', dtype=str)
df = pd.merge(df, df_IPS_sig_group, left_on ='IPS_fisher_IPS_20_vs_26_results', right_on ='otu', how ='left')
cols_to_drop = [
    'qlen', 'sseqid', 'slen', 'qseq', 'sseq', 'evalue', 'bitscore',
    'pident', 'qcovhsp', 'salltitles', 'qseqid_y', 'qseqid_x'
]

df = df.drop(columns=cols_to_drop)
df

# %%
dfm = pd.merge (df, dfm, left_on = 'feature_id', right_on = 'qseqid', how = 'left')

# %%
dfm.columns

# %%
#filter for only VF with >= 75% sequence identity
dfm['pident_y'] = pd.to_numeric(dfm['pident_y'], errors='coerce')


df_CARD = dfm[dfm['pident_y'] >= 75]

# %%
#pivot IPS by VFDB, lists top  VF gene

pivot_df = (
    df_CARD.dropna(subset=['fisher_IPS_20_vs_26_results'])
      .pivot_table(
          index='fisher_IPS_20_vs_26_results',
          values='ARO Name',
          aggfunc=lambda x: Counter(x.dropna()).most_common(1)[0][0] if len(x.dropna()) > 0 else None
      )
)
pivot_df


pivot_df = pivot_df.reset_index()
pivot_df = pivot_df.rename(columns={'salltitles_y': 'ARO Name'})
pivot_df

# %%
dfm = pd.merge(dfm, pivot_df, on = 'fisher_IPS_20_vs_26_results', how = 'left')

# for feature_ids with <35% VF similiarity, need to remove VF_consensus label
dfm.loc[dfm['pident_y'] < 75, 'VF_consensus'] = np.nan

# %%
dfm

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '20_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['ARO Name_y'])
               .groupby(['ARO Name_y', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='ARO Name_y',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(10).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['ARO Name_y', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='ARO Name_y',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(10)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

final_wide_df_top25 = final_wide_df_top25 * 100


# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

# %%
filtered_df = dfm[dfm['IPS_sig_group']== '26_year']
filtered_df

unique_species= len(filtered_df['species'].unique())
unique_species

unique_genes = len(filtered_df['feature_id'].unique())
unique_genes

pivot_df = (
    filtered_df.dropna(subset=['ARO Name_y'])
               .groupby(['ARO Name_y', 'species'])
               .size()       # count of each species per module
               .div(unique_genes)  # divide by your number
               .unstack(fill_value=0)  # make species columns
)
pivot_df

long_df = pivot_df.reset_index().melt(
    id_vars='ARO Name_y',       # keep 'module' as identifier
    var_name='species',     # name of the column for species
    value_name='ratio'      # name of the column for the values (size / unique_genes)
)

long_df

# get top representative species

# Step 3: compute total abundance per species
species_totals = long_df.groupby('species')['ratio'].sum()

# Step 4: identify top 10 species
top_species = species_totals.nlargest(10).index

# Step 5: group species not in top 10 into 'Other'
long_df['species_grouped'] = long_df['species'].where(
    long_df['species'].isin(top_species),
    'Other'
)

# Step 6: aggregate ratios per module and grouped species
final_long_df = (
    long_df.groupby(['ARO Name_y', 'species_grouped'])['ratio']
           .sum()
           .reset_index()
)

# Optional Step 7: pivot back to wide format (top 10 + Other as columns)
final_wide_df = final_long_df.pivot(
    index='ARO Name_y',
    columns='species_grouped',
    values='ratio'
).fillna(0)


#get top most prevalent pathways
final_wide_df_top25 = (
    final_wide_df.assign(total=final_wide_df.sum(axis=1))
                 .sort_values('total', ascending=True)  # highest totals first
                 .tail(10)                               # keep top 25 rows
                 .drop(columns='total')                  # remove helper column
)

# Step 2: plot
final_wide_df_top25.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)

species_totals = final_wide_df_top25.sum().sort_values(ascending=False)

final_wide_df_top25 = final_wide_df_top25 * 100


# Step 2: reorder columns by total abundance
final_wide_df_top25_sorted_cols = final_wide_df_top25[species_totals.index]

# Step 3: plot
final_wide_df_top25_sorted_cols.plot.barh(
    stacked=True,
    figsize=(10, 10),
    colormap='tab20'
)
